# %%
## Importing necessary libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
## Importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
## Importing Telecom data
data = pd.read_csv("C:\\telecom_churn_data.csv")

# %%
data.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Columns: 226 entries, mobile_number to sep_vbc_3g
# dtypes: float64(179), int64(35), object(12)
# memory usage: 172.4+ MB

# %%
data.describe()
# Out:
#        mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count   9.999900e+04    99999.0         98981.0         98981.0
# mean    7.001207e+09      109.0             0.0             0.0
# std     6.956694e+05        0.0             0.0             0.0
# min     7.000000e+09      109.0             0.0             0.0
# 25%     7.000606e+09      109.0             0.0             0.0
# 50%     7.001205e+09      109.0             0.0             0.0
# 75%     7.001812e+09      109.0             0.0             0.0
# max     7.002411e+09      109.0             0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8        arpu_9  \
# count         98981.0  99999.000000  99999.000000  99999.000000  99999.000000
# mean              0.0    282.987358    278.536648    279.154731    261.645069
# std               0.0    328.439770    338.156291    344.474791    341.998630
# ...

# %%
##Creating a new column for End date of the 4 months
data['last_date_of_month_6'] = '6/30/2014'
data['last_date_of_month_7'] = '7/31/2014'
data['last_date_of_month_8'] = '8/31/2014'
data['last_date_of_month_9'] = '9/30/2014'
data['loc_og_t2o_mou'] = 0
data['std_og_t2o_mou'] = 0
data['loc_ic_t2o_mou'] = 0

# %%
##Imputing the value of 0 for Customers who have total_og_mou as 0
col_up = ['onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 'onnet_mou_9', 'offnet_mou_6', 'offnet_mou_7', 'offnet_mou_8', 'offnet_mou_9', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8', 'roam_og_mou_9', 'loc_og_t2t_mou_6', 'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8', 'loc_og_t2t_mou_9', 'loc_og_t2m_mou_6', 'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2m_mou_9', 'loc_og_t2f_mou_6', 'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8', 'loc_og_t2f_mou_9', 'loc_og_t2c_mou_6', 'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8', 'loc_og_t2c_mou_9', 'loc_og_mou_6', 'loc_og_mou_7', 'loc_og_mou_8', 'loc_og_mou_9', 'std_og_t2t_mou_6', 'std_og_t2t_mou_7', 'std_og_t2t_mou_8', 'std_og_t2t_mou_9', 'std_og_t2m_mou_6', 'std_og_t2m_mou_7', 'std_og_t2m_mou_8', 'std_og_t2m_mou_9', 'std_og_t2f_mou_6', 'std_og_t2f_mou_7', 'std_og_t2f_mou_8', 'std_og_t2f_mou_9', 'std_og_t2c_mou_6', 'std_og_t2c_mou_7', 'std_og_t2c_mou_8', 'std_og_t2c_mou_9', 'std_og_mou_6', 'std_og_mou_7', 'std_og_mou_8', 'std_og_mou_9', 'isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8', 'isd_og_mou_9', 'spl_og_mou_6', 'spl_og_mou_7', 'spl_og_mou_8', 'spl_og_mou_9', 'og_others_6', 'og_others_7', 'og_others_8', 'og_others_9']
data[col_up] = data[col_up].fillna(0)
data.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109               0               0               0
# 1     7001865778        109               0               0               0
# 2     7001625959        109               0               0               0
# 3     7001204172        109               0               0               0
# 4     7000142493        109               0               0               0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# ...

# %%
##Imputing the value of 0 for Customers who have total_ic_mou as 0
col_up1 = ['roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8', 'roam_ic_mou_9', 'loc_ic_t2f_mou_9', 'loc_ic_mou_6', 'loc_ic_mou_7', 'loc_ic_mou_8', 'loc_ic_mou_9', 'std_ic_t2t_mou_6', 'std_ic_t2t_mou_7', 'std_ic_t2t_mou_8', 'std_ic_t2t_mou_9', 'std_ic_t2m_mou_6', 'std_ic_t2m_mou_7', 'std_ic_t2m_mou_8', 'std_ic_t2m_mou_9', 'std_ic_t2f_mou_6', 'std_ic_t2f_mou_7', 'std_ic_t2f_mou_8', 'std_ic_t2f_mou_9', 'std_ic_t2o_mou_6', 'std_ic_t2o_mou_7', 'std_ic_t2o_mou_8', 'std_ic_t2o_mou_9', 'std_ic_mou_6', 'std_ic_mou_7', 'std_ic_mou_8', 'std_ic_mou_9', 'spl_ic_mou_6', 'spl_ic_mou_7', 'spl_ic_mou_8', 'spl_ic_mou_9', 'isd_ic_mou_6', 'isd_ic_mou_7', 'isd_ic_mou_8', 'isd_ic_mou_9', 'ic_others_6', 'ic_others_7', 'ic_others_8', 'ic_others_9', 'loc_ic_t2t_mou_6', 'loc_ic_t2t_mou_7', 'loc_ic_t2t_mou_8', 'loc_ic_t2t_mou_9', 'loc_ic_t2m_mou_6', 'loc_ic_t2m_mou_7', 'loc_ic_t2m_mou_8', 'loc_ic_t2m_mou_9', 'loc_ic_t2f_mou_6', 'loc_ic_t2f_mou_7', 'loc_ic_t2f_mou_8']
data[col_up1] = data[col_up1].fillna(0)
data.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109               0               0               0
# 1     7001865778        109               0               0               0
# 2     7001625959        109               0               0               0
# 3     7001204172        109               0               0               0
# 4     7000142493        109               0               0               0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# ...

# %%
## Filling null-values for data_pack recharge_amount and count to 0 
col_up2 = ['total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8', 'total_rech_data_9', 'max_rech_data_6', 'max_rech_data_7', 'max_rech_data_8', 'max_rech_data_9', 'count_rech_2g_6', 'count_rech_2g_7', 'count_rech_2g_8', 'count_rech_2g_9', 'count_rech_3g_6', 'count_rech_3g_7', 'count_rech_3g_8', 'count_rech_3g_9', 'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8', 'av_rech_amt_data_9']
data[col_up2] = data[col_up2].fillna(0)
data.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109               0               0               0
# 1     7001865778        109               0               0               0
# 2     7001625959        109               0               0               0
# 3     7001204172        109               0               0               0
# 4     7000142493        109               0               0               0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# ...

# %%
##Creating a column for total recharge amount for 6 7 8 & 9 months
data['total_data_rech_amt_6'] = data['total_rech_data_6'] * data['av_rech_amt_data_6']
data['total_data_rech_amt_7'] = data['total_rech_data_7'] * data['av_rech_amt_data_7']
data['total_data_rech_amt_8'] = data['total_rech_data_8'] * data['av_rech_amt_data_8']
data['total_data_rech_amt_9'] = data['total_rech_data_9'] * data['av_rech_amt_data_9']
data.head(10)
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109               0               0               0
# 1     7001865778        109               0               0               0
# 2     7001625959        109               0               0               0
# 3     7001204172        109               0               0               0
# 4     7000142493        109               0               0               0
# 5     7000286308        109               0               0               0
# 6     7001051193        109               0               0               0
# 7     7000701601        109               0               0               0
# 8     7001524846        109               0               0               0
# 9     7001864400        109               0               0               0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# ...

# %%
## Adding the values of data recharge amount + recharge amount into a column called total_rech which gives full amount
## gained by the Telecom company from said customer for 6 7 8 9 months

# %%
data['total_rech_6'] = data['total_data_rech_amt_6'] + data['total_rech_amt_6']
data['total_rech_7'] = data['total_data_rech_amt_7'] + data['total_rech_amt_7']
data['total_rech_8'] = data['total_data_rech_amt_8'] + data['total_rech_amt_8']
data['total_rech_9'] = data['total_data_rech_amt_9'] + data['total_rech_amt_9']
data.head(10)
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109               0               0               0
# 1     7001865778        109               0               0               0
# 2     7001625959        109               0               0               0
# 3     7001204172        109               0               0               0
# 4     7000142493        109               0               0               0
# 5     7000286308        109               0               0               0
# 6     7001051193        109               0               0               0
# 7     7000701601        109               0               0               0
# 8     7001524846        109               0               0               0
# 9     7001864400        109               0               0               0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# ...

# %%
## Now we check who are the high paying customers (70 percentile customer) average recharge amount for June & July

# %%
data['total_rech_6_7'] = data['total_rech_6'] + data['total_rech_7']
round(data['total_rech_6_7'].mean(), 2)
# Out:
# 970.66

# %%
## For 70 percentile
data['total_rech_6_7'].quantile(0.7)
# Out:
# 956.0

# %%
##Now we filter the 70 percentile customers from low paying customers
filter_data = data[(data['total_rech_6_7'] >= data['total_rech_6_7'].quantile(0.7))]
filter_data.head()
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0      7000842753        109               0               0               0
# 7      7000701601        109               0               0               0
# 8      7001524846        109               0               0               0
# 21     7002124215        109               0               0               0
# 23     7000887461        109               0               0               0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0             6/30/2014            7/31/2014            8/31/2014
# 7             6/30/2014            7/31/2014            8/31/2014
# 8             6/30/2014            7/31/2014            8/31/2014
# 21            6/30/2014            7/31/2014            8/31/2014
# 23            6/30/2014            7/31/2014            8/31/2014
#
#    last_date_of_month_9    arpu_6  ...  sep_vbc_3g  total_data_rech_amt_6  \
# ...

# %%
## filtering how many high paying customers have churned at the end of 9 th month
filter_data['Churn'] = 0
filter_data['Churn'] = filter_data.index.isin(filter_data[(filter_data.total_og_mou_9 != 0) | (filter_data.total_ic_mou_9 != 0) | (filter_data.vol_2g_mb_9 != 0) | (filter_data.vol_3g_mb_9 != 0)].index)
filter_data.Churn = filter_data.Churn.apply(lambda x: 1 if x==False else 0)

filter_data.head()
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0      7000842753        109               0               0               0
# 7      7000701601        109               0               0               0
# 8      7001524846        109               0               0               0
# 21     7002124215        109               0               0               0
# 23     7000887461        109               0               0               0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0             6/30/2014            7/31/2014            8/31/2014
# 7             6/30/2014            7/31/2014            8/31/2014
# 8             6/30/2014            7/31/2014            8/31/2014
# 21            6/30/2014            7/31/2014            8/31/2014
# 23            6/30/2014            7/31/2014            8/31/2014
#
#    last_date_of_month_9    arpu_6  ...  total_data_rech_amt_6  \
# ...

# %%
filter_data[['mobile_number','total_ic_mou_9','total_og_mou_9','vol_2g_mb_9','vol_3g_mb_9','Churn']]
# Out:
#        mobile_number  total_ic_mou_9  total_og_mou_9  vol_2g_mb_9  \
# 0         7000842753            0.00            0.00         0.00
# 7         7000701601            0.00            0.00         0.00
# 8         7001524846           34.91          142.18         0.00
# 21        7002124215          252.61         1031.53         0.00
# 23        7000887461          127.48          127.63        13.93
# ...              ...             ...             ...          ...
# 99981     7000630859          391.63           64.21         0.00
# 99984     7000661676          149.26           14.44       723.41
# 99986     7001729035          547.11         1095.24         9.14
# 99988     7002111859          265.84          182.16         0.05
# 99997     7000498689            2.21            0.00        85.67
#
#        vol_3g_mb_9  Churn
# 0             0.00      1
# 7             0.00      1
# 8             0.00      0
# 21            0.00      0
# 23          314.74      0
# ...

# %%
## Creating Primary model prime1 with the dataset of high paying 70 perentile customers with high data consumption for
## 2G & 3G data

# %%
columnslist = ['mobile_number', 'circle_id', 'loc_og_t2o_mou', 'std_og_t2o_mou', 'loc_ic_t2o_mou', 'last_date_of_month_6', 'last_date_of_month_7', 'last_date_of_month_8', 'arpu_6', 'arpu_7', 'arpu_8', 'onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 'offnet_mou_6', 'offnet_mou_7', 'offnet_mou_8', 'roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8', 'loc_og_t2t_mou_6', 'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8', 'loc_og_t2m_mou_6', 'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2f_mou_6', 'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8', 'loc_og_t2c_mou_6', 'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8', 'loc_og_mou_6', 'loc_og_mou_7', 'loc_og_mou_8', 'std_og_t2t_mou_6', 'std_og_t2t_mou_7', 'std_og_t2t_mou_8', 'std_og_t2m_mou_6', 'std_og_t2m_mou_7', 'std_og_t2m_mou_8', 'std_og_t2f_mou_6', 'std_og_t2f_mou_7', 'std_og_t2f_mou_8', 'std_og_t2c_mou_6', 'std_og_t2c_mou_7', 'std_og_t2c_mou_8', 'std_og_mou_6', 'std_og_mou_7', 'std_og_mou_8', 'isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8', 'spl_og_mou_6', 'spl_og_mou_7', 'spl_og_mou_8', 'og_others_6', 'og_others_7', 'og_others_8', 'total_og_mou_6', 'total_og_mou_7', 'total_og_mou_8', 'loc_ic_t2t_mou_6', 'loc_ic_t2t_mou_7', 'loc_ic_t2t_mou_8', 'loc_ic_t2m_mou_6', 'loc_ic_t2m_mou_7', 'loc_ic_t2m_mou_8', 'loc_ic_t2f_mou_6', 'loc_ic_t2f_mou_7', 'loc_ic_t2f_mou_8', 'loc_ic_mou_6', 'loc_ic_mou_7', 'loc_ic_mou_8', 'std_ic_t2t_mou_6', 'std_ic_t2t_mou_7', 'std_ic_t2t_mou_8', 'std_ic_t2m_mou_6', 'std_ic_t2m_mou_7', 'std_ic_t2m_mou_8', 'std_ic_t2f_mou_6', 'std_ic_t2f_mou_7', 'std_ic_t2f_mou_8', 'std_ic_t2o_mou_6', 'std_ic_t2o_mou_7', 'std_ic_t2o_mou_8', 'std_ic_mou_6', 'std_ic_mou_7', 'std_ic_mou_8', 'total_ic_mou_6', 'total_ic_mou_7', 'total_ic_mou_8', 'spl_ic_mou_6', 'spl_ic_mou_7', 'spl_ic_mou_8', 'isd_ic_mou_6', 'isd_ic_mou_7', 'isd_ic_mou_8', 'ic_others_6', 'ic_others_7', 'ic_others_8', 'total_rech_num_6', 'total_rech_num_7', 'total_rech_num_8', 'total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8', 'max_rech_amt_6', 'max_rech_amt_7', 'max_rech_amt_8', 'date_of_last_rech_6', 'date_of_last_rech_7', 'date_of_last_rech_8', 'last_day_rch_amt_6', 'last_day_rch_amt_7', 'last_day_rch_amt_8', 'date_of_last_rech_data_6', 'date_of_last_rech_data_7', 'date_of_last_rech_data_8', 'total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8', 'max_rech_data_6', 'max_rech_data_7', 'max_rech_data_8', 'count_rech_2g_6', 'count_rech_2g_7', 'count_rech_2g_8', 'count_rech_3g_6', 'count_rech_3g_7', 'count_rech_3g_8', 'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8', 'vol_2g_mb_6', 'vol_2g_mb_7', 'vol_2g_mb_8', 'vol_3g_mb_6', 'vol_3g_mb_7', 'vol_3g_mb_8', 'arpu_3g_6', 'arpu_3g_7', 'arpu_3g_8', 'arpu_2g_6', 'arpu_2g_7', 'arpu_2g_8', 'night_pck_user_6', 'night_pck_user_7', 'night_pck_user_8', 'monthly_2g_6', 'monthly_2g_7', 'monthly_2g_8', 'sachet_2g_6', 'sachet_2g_7', 'sachet_2g_8', 'monthly_3g_6', 'monthly_3g_7', 'monthly_3g_8', 'sachet_3g_6', 'sachet_3g_7', 'sachet_3g_8', 'fb_user_6', 'fb_user_7', 'fb_user_8', 'aon', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g', 'sep_vbc_3g', 'total_data_rech_amt_6', 'total_data_rech_amt_7', 'total_data_rech_amt_8', 'total_rech_6', 'total_rech_7', 'total_rech_8', 'Churn']
prime1 = filter_data[columnslist]
prime1.head()
# Out:
#     mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0      7000842753        109               0               0               0
# 7      7000701601        109               0               0               0
# 8      7001524846        109               0               0               0
# 21     7002124215        109               0               0               0
# 23     7000887461        109               0               0               0
#
#    last_date_of_month_6 last_date_of_month_7 last_date_of_month_8    arpu_6  \
# 0             6/30/2014            7/31/2014            8/31/2014   197.385
# 7             6/30/2014            7/31/2014            8/31/2014  1069.180
# 8             6/30/2014            7/31/2014            8/31/2014   378.721
# 21            6/30/2014            7/31/2014            8/31/2014   514.453
# 23            6/30/2014            7/31/2014            8/31/2014    74.350
#
# ...

# %%
## Columns with 0 can be dropped as they are no longer important
prime1 = prime1.drop(columns=['loc_og_t2o_mou', 'std_og_t2o_mou', 'loc_ic_t2o_mou', 'std_og_t2c_mou_6', 'std_og_t2c_mou_7', 'std_og_t2c_mou_8','std_ic_t2o_mou_6', 'std_ic_t2o_mou_7', 'std_ic_t2o_mou_8'], axis=1)

# %%
prime1.head()
# Out:
#     mobile_number  circle_id last_date_of_month_6 last_date_of_month_7  \
# 0      7000842753        109            6/30/2014            7/31/2014
# 7      7000701601        109            6/30/2014            7/31/2014
# 8      7001524846        109            6/30/2014            7/31/2014
# 21     7002124215        109            6/30/2014            7/31/2014
# 23     7000887461        109            6/30/2014            7/31/2014
#
#    last_date_of_month_8    arpu_6    arpu_7    arpu_8  onnet_mou_6  \
# 0             8/31/2014   197.385   214.816   213.803         0.00
# 7             8/31/2014  1069.180  1349.850  3171.480        57.84
# 8             8/31/2014   378.721   492.223   137.362       413.69
# 21            8/31/2014   514.453   597.753   637.760       102.41
# 23            8/31/2014    74.350   193.897   366.966        48.96
#
#     onnet_mou_7  ...  jul_vbc_3g  jun_vbc_3g  sep_vbc_3g  \
# 0          0.00  ...        0.00      101.20        3.58
# ...

# %%
## The above is a clear high paying customer data

# %%
## Obtaining Trur or False (0&1) values for the prime1 dataset

# %%
prime1_class1 = prime1[['arpu_6', 'arpu_7', 'arpu_8', 'onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 'offnet_mou_6', 'offnet_mou_7', 'offnet_mou_8', 'roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8', 'loc_og_t2t_mou_6', 'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8', 'loc_og_t2m_mou_6', 'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2f_mou_6', 'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8', 'loc_og_t2c_mou_6', 'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8', 'loc_og_mou_6', 'loc_og_mou_7', 'loc_og_mou_8', 'std_og_t2t_mou_6', 'std_og_t2t_mou_7', 'std_og_t2t_mou_8', 'std_og_t2m_mou_6', 'std_og_t2m_mou_7', 'std_og_t2m_mou_8', 'std_og_t2f_mou_6', 'std_og_t2f_mou_7', 'std_og_t2f_mou_8', 'std_og_mou_6', 'std_og_mou_7', 'std_og_mou_8', 'isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8', 'spl_og_mou_6', 'spl_og_mou_7', 'spl_og_mou_8', 'og_others_6', 'og_others_7', 'og_others_8', 'total_og_mou_6', 'total_og_mou_7', 'total_og_mou_8', 'loc_ic_t2t_mou_6', 'loc_ic_t2t_mou_7', 'loc_ic_t2t_mou_8', 'loc_ic_t2m_mou_6', 'loc_ic_t2m_mou_7', 'loc_ic_t2m_mou_8', 'loc_ic_t2f_mou_6', 'loc_ic_t2f_mou_7', 'loc_ic_t2f_mou_8', 'loc_ic_mou_6', 'loc_ic_mou_7', 'loc_ic_mou_8', 'std_ic_t2t_mou_6', 'std_ic_t2t_mou_7', 'std_ic_t2t_mou_8', 'std_ic_t2m_mou_6', 'std_ic_t2m_mou_7', 'std_ic_t2m_mou_8', 'std_ic_t2f_mou_6', 'std_ic_t2f_mou_7', 'std_ic_t2f_mou_8', 'std_ic_mou_6', 'std_ic_mou_7', 'std_ic_mou_8', 'total_ic_mou_6', 'total_ic_mou_7', 'total_ic_mou_8', 'spl_ic_mou_6', 'spl_ic_mou_7', 'spl_ic_mou_8', 'isd_ic_mou_6', 'isd_ic_mou_7', 'isd_ic_mou_8', 'ic_others_6', 'ic_others_7', 'ic_others_8', 'total_rech_num_6', 'total_rech_num_7', 'total_rech_num_8', 'total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8', 'max_rech_amt_6', 'max_rech_amt_7', 'max_rech_amt_8', 'last_day_rch_amt_6', 'last_day_rch_amt_7', 'last_day_rch_amt_8', 'total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8', 'max_rech_data_6', 'max_rech_data_7', 'max_rech_data_8', 'count_rech_2g_6', 'count_rech_2g_7', 'count_rech_2g_8', 'count_rech_3g_6', 'count_rech_3g_7', 'count_rech_3g_8', 'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8', 'vol_2g_mb_6', 'vol_2g_mb_7', 'vol_2g_mb_8', 'vol_3g_mb_6', 'vol_3g_mb_7', 'vol_3g_mb_8', 'arpu_3g_6', 'arpu_3g_7', 'arpu_3g_8', 'arpu_2g_6', 'arpu_2g_7', 'arpu_2g_8', 'night_pck_user_6', 'night_pck_user_7', 'night_pck_user_8', 'monthly_2g_6', 'monthly_2g_7', 'monthly_2g_8', 'sachet_2g_6', 'sachet_2g_7', 'sachet_2g_8', 'monthly_3g_6', 'monthly_3g_7', 'monthly_3g_8', 'sachet_3g_6', 'sachet_3g_7', 'sachet_3g_8', 'fb_user_6', 'fb_user_7', 'fb_user_8', 'aon', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g', 'sep_vbc_3g', 'total_data_rech_amt_6', 'total_data_rech_amt_7', 'total_data_rech_amt_8', 'total_rech_6', 'total_rech_7', 'total_rech_8']]
prime1_class2 = prime1.Churn

# %%
## Focusing on prime1_class1, and removing unwanted variables

# %%
prime1_class1 = prime1_class1.drop(columns=['fb_user_6','fb_user_7','fb_user_8',])
prime1_class1 = prime1_class1.fillna(0)

# %%
prime1_class1 = prime1_class1.drop(columns=['onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 'offnet_mou_6', 'offnet_mou_7', 'offnet_mou_8'])

# %%
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  roam_ic_mou_6  roam_ic_mou_7  roam_ic_mou_8  \
# 0    197.385   214.816   213.803           0.00           0.00           0.00
# 7   1069.180  1349.850  3171.480          16.23          33.49          31.64
# 8    378.721   492.223   137.362           0.00           0.00           0.00
# 21   514.453   597.753   637.760           0.00           0.00           0.00
# 23    74.350   193.897   366.966           0.00           0.00           0.00
#
#     roam_og_mou_6  roam_og_mou_7  roam_og_mou_8  loc_og_t2t_mou_6  ...  \
# 0            0.00           0.00           0.00              0.00  ...
# 7           23.74          12.59          38.06             51.39  ...
# 8            0.00           0.00           0.00            297.13  ...
# 21           0.00           0.00           0.00              4.48  ...
# 23           0.00           0.00           0.00             48.96  ...
#
# ...

# %%
## Adding up values for roaming into one cohesive column in prime1_class1
prime1_class1['roam_any_6'] = prime1_class1[['roam_ic_mou_6', 'roam_og_mou_6']].sum(axis = 1)
prime1_class1['roam_any_7'] = prime1_class1[['roam_ic_mou_7', 'roam_og_mou_7']].sum(axis = 1)
prime1_class1['roam_any_8'] = prime1_class1[['roam_ic_mou_8', 'roam_og_mou_8']].sum(axis = 1)
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  roam_ic_mou_6  roam_ic_mou_7  roam_ic_mou_8  \
# 0    197.385   214.816   213.803           0.00           0.00           0.00
# 7   1069.180  1349.850  3171.480          16.23          33.49          31.64
# 8    378.721   492.223   137.362           0.00           0.00           0.00
# 21   514.453   597.753   637.760           0.00           0.00           0.00
# 23    74.350   193.897   366.966           0.00           0.00           0.00
#
#     roam_og_mou_6  roam_og_mou_7  roam_og_mou_8  loc_og_t2t_mou_6  ...  \
# 0            0.00           0.00           0.00              0.00  ...
# 7           23.74          12.59          38.06             51.39  ...
# 8            0.00           0.00           0.00            297.13  ...
# 21           0.00           0.00           0.00              4.48  ...
# 23           0.00           0.00           0.00             48.96  ...
#
#     sep_vbc_3g  total_data_rech_amt_6  total_data_rech_amt_7  \
# ...

# %%
##Checking Roaming data we need to have a classifier for the same in 6 7 8 9 months
prime1_class1['roam_any_6'] = prime1_class1['roam_any_6'].apply(lambda x: 1 if (x>0) else 0)
prime1_class1['roam_any_7'] = prime1_class1['roam_any_7'].apply(lambda x: 1 if (x>0) else 0)
prime1_class1['roam_any_8'] = prime1_class1['roam_any_8'].apply(lambda x: 1 if (x>0) else 0)
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  roam_ic_mou_6  roam_ic_mou_7  roam_ic_mou_8  \
# 0    197.385   214.816   213.803           0.00           0.00           0.00
# 7   1069.180  1349.850  3171.480          16.23          33.49          31.64
# 8    378.721   492.223   137.362           0.00           0.00           0.00
# 21   514.453   597.753   637.760           0.00           0.00           0.00
# 23    74.350   193.897   366.966           0.00           0.00           0.00
#
#     roam_og_mou_6  roam_og_mou_7  roam_og_mou_8  loc_og_t2t_mou_6  ...  \
# 0            0.00           0.00           0.00              0.00  ...
# 7           23.74          12.59          38.06             51.39  ...
# 8            0.00           0.00           0.00            297.13  ...
# 21           0.00           0.00           0.00              4.48  ...
# 23           0.00           0.00           0.00             48.96  ...
#
#     sep_vbc_3g  total_data_rech_amt_6  total_data_rech_amt_7  \
# ...

# %%
prime1_class1 = prime1_class1.drop(columns=['roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8', 'roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8'])
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  loc_og_t2t_mou_6  loc_og_t2t_mou_7  \
# 0    197.385   214.816   213.803              0.00              0.00
# 7   1069.180  1349.850  3171.480             51.39             31.38
# 8    378.721   492.223   137.362            297.13            217.59
# 21   514.453   597.753   637.760              4.48              6.16
# 23    74.350   193.897   366.966             48.96             50.66
#
#     loc_og_t2t_mou_8  loc_og_t2m_mou_6  loc_og_t2m_mou_7  loc_og_t2m_mou_8  \
# 0               0.00              0.00              0.00              0.00
# 7              40.28            308.63            447.38            162.28
# 8              12.49             80.96             70.58             50.54
# 21             23.34             91.81             87.93            104.81
# 23             33.58             82.94             83.01            148.56
#
#     loc_og_t2f_mou_6  ...  sep_vbc_3g  total_data_rech_amt_6  \
# ...

# %%
prime1_class1['local_any_6'] = prime1_class1[['loc_og_t2t_mou_6', 'loc_og_t2m_mou_6', 'loc_og_t2f_mou_6', 'loc_og_t2c_mou_6', 'loc_og_mou_6', 'loc_ic_t2t_mou_6', 'loc_ic_t2m_mou_6', 'loc_ic_t2f_mou_6', 'loc_ic_mou_6']].sum(axis=1)
prime1_class1['local_any_7'] = prime1_class1[['loc_og_t2t_mou_7', 'loc_og_t2m_mou_7', 'loc_og_t2f_mou_7', 'loc_og_t2c_mou_7', 'loc_og_mou_7', 'loc_ic_t2t_mou_7', 'loc_ic_t2m_mou_7', 'loc_ic_t2f_mou_7', 'loc_ic_mou_7']].sum(axis=1)
prime1_class1['local_any_8'] = prime1_class1[['loc_og_t2t_mou_8', 'loc_og_t2m_mou_8', 'loc_og_t2f_mou_8', 'loc_og_t2c_mou_8', 'loc_og_mou_8', 'loc_ic_t2t_mou_8', 'loc_ic_t2m_mou_8', 'loc_ic_t2f_mou_8', 'loc_ic_mou_8']].sum(axis=1)

prime1_class1['local_any_6'] = prime1_class1['local_any_6'].apply(lambda x: 1 if (x > 0) else 0)
prime1_class1['local_any_7'] = prime1_class1['local_any_7'].apply(lambda x: 1 if (x > 0) else 0)
prime1_class1['local_any_8'] = prime1_class1['local_any_8'].apply(lambda x: 1 if (x > 0) else 0)

prime1_class1 = prime1_class1.drop(columns=['loc_og_t2t_mou_6', 'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8', 'loc_og_t2m_mou_6', 'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2f_mou_6', 'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8', 'loc_og_t2c_mou_6', 'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8', 'loc_og_mou_6', 'loc_og_mou_7', 'loc_og_mou_8', 'loc_ic_t2t_mou_6', 'loc_ic_t2t_mou_7', 'loc_ic_t2t_mou_8', 'loc_ic_t2m_mou_6', 'loc_ic_t2m_mou_7', 'loc_ic_t2m_mou_8', 'loc_ic_t2f_mou_6', 'loc_ic_t2f_mou_7', 'loc_ic_t2f_mou_8', 'loc_ic_mou_6', 'loc_ic_mou_7', 'loc_ic_mou_8'])

# %%
## The above command for classification was successfully executed but the error is shown due to double click
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  std_og_t2t_mou_6  std_og_t2t_mou_7  \
# 0    197.385   214.816   213.803              0.00              0.00
# 7   1069.180  1349.850  3171.480              4.30             23.29
# 8    378.721   492.223   137.362            116.56            133.43
# 21   514.453   597.753   637.760             97.93            125.94
# 23    74.350   193.897   366.966              0.00              0.00
#
#     std_og_t2t_mou_8  std_og_t2m_mou_6  std_og_t2m_mou_7  std_og_t2m_mou_8  \
# 0               0.00              0.00              0.00              0.00
# 7              12.01             49.89             31.76             49.14
# 8              22.58             13.69             10.04             75.69
# 21             61.79            665.36            808.74            876.99
# 23              0.00              2.36              6.35             39.61
#
#     std_og_t2f_mou_6  ...  total_data_rech_amt_8  total_rech_6  total_rech_7  \
# ...

# %%
## The same kind of classification is done for standard data charges
prime1_class1['std_any_6'] = prime1_class1[['std_og_t2t_mou_6', 'std_og_t2m_mou_6', 'std_og_t2f_mou_6', 'std_og_mou_6', 'std_ic_t2t_mou_6', 'std_ic_t2m_mou_6', 'std_ic_t2f_mou_6', 'std_ic_mou_6']].sum(axis=1)
prime1_class1['std_any_7'] = prime1_class1[['std_og_t2t_mou_7', 'std_og_t2m_mou_7', 'std_og_t2f_mou_7', 'std_og_mou_7', 'std_ic_t2t_mou_7', 'std_ic_t2m_mou_7', 'std_ic_t2f_mou_7', 'std_ic_mou_7']].sum(axis=1)
prime1_class1['std_any_8'] = prime1_class1[['std_og_t2t_mou_8', 'std_og_t2m_mou_8', 'std_og_t2f_mou_8', 'std_og_mou_8', 'std_ic_t2t_mou_8', 'std_ic_t2m_mou_8', 'std_ic_t2f_mou_8', 'std_ic_mou_8']].sum(axis=1)

prime1_class1['std_any_6'] = prime1_class1['std_any_6'].apply(lambda x: 1 if (x > 0) else 0)
prime1_class1['std_any_7'] = prime1_class1['std_any_7'].apply(lambda x: 1 if (x > 0) else 0)
prime1_class1['std_any_8'] = prime1_class1['std_any_8'].apply(lambda x: 1 if (x > 0) else 0)
prime1_class1 = prime1_class1.drop(columns=['std_og_t2t_mou_6', 'std_og_t2t_mou_7', 'std_og_t2t_mou_8', 'std_og_t2m_mou_6', 'std_og_t2m_mou_7', 'std_og_t2m_mou_8', 'std_og_t2f_mou_6', 'std_og_t2f_mou_7', 'std_og_t2f_mou_8', 'std_og_mou_6', 'std_og_mou_7', 'std_og_mou_8', 'std_ic_t2t_mou_6', 'std_ic_t2t_mou_7', 'std_ic_t2t_mou_8', 'std_ic_t2m_mou_6', 'std_ic_t2m_mou_7', 'std_ic_t2m_mou_8', 'std_ic_t2f_mou_6', 'std_ic_t2f_mou_7', 'std_ic_t2f_mou_8', 'std_ic_mou_6', 'std_ic_mou_7', 'std_ic_mou_8'])

# %%
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  isd_og_mou_6  isd_og_mou_7  isd_og_mou_8  \
# 0    197.385   214.816   213.803           0.0          0.00          0.00
# 7   1069.180  1349.850  3171.480           0.0          0.18         10.01
# 8    378.721   492.223   137.362           0.0          0.00          0.00
# 21   514.453   597.753   637.760           0.0          0.00          0.00
# 23    74.350   193.897   366.966           0.0          0.01          0.00
#
#     spl_og_mou_6  spl_og_mou_7  spl_og_mou_8  og_others_6  ...  total_rech_8  \
# 0            0.0           0.0          0.00          0.0  ...         504.0
# 7            4.5           0.0          6.50          0.0  ...        3638.0
# 8            0.0           0.0         10.23          0.0  ...         327.0
# 21           0.0           0.0          0.00          0.0  ...         718.0
# 23           0.1           0.0         17.71          0.0  ...         979.0
#
# ...

# %%
## The same kind of classification is done for isd & special data charges
prime1_class1['spl_any_6'] = prime1_class1[['isd_og_mou_6', 'spl_og_mou_6', 'og_others_6', 'spl_ic_mou_6', 'isd_ic_mou_6', 'ic_others_6']].sum(axis=1)
prime1_class1['spl_any_7'] = prime1_class1[['isd_og_mou_7', 'spl_og_mou_7', 'og_others_7', 'spl_ic_mou_7', 'isd_ic_mou_7', 'ic_others_7']].sum(axis=1)
prime1_class1['spl_any_8'] = prime1_class1[['isd_og_mou_8', 'spl_og_mou_8', 'og_others_8', 'spl_ic_mou_8', 'isd_ic_mou_8', 'ic_others_8']].sum(axis=1)

prime1_class1['spl_any_6'] = prime1_class1['spl_any_6'].apply(lambda x: 1 if (x > 0) else 0)
prime1_class1['spl_any_7'] = prime1_class1['spl_any_7'].apply(lambda x: 1 if (x > 0) else 0)
prime1_class1['spl_any_8'] = prime1_class1['spl_any_8'].apply(lambda x: 1 if (x > 0) else 0)

prime1_class1 = prime1_class1.drop(columns=['isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8', 'spl_og_mou_6', 'spl_og_mou_7', 'spl_og_mou_8', 'og_others_6', 'og_others_7', 'og_others_8',  'spl_ic_mou_6', 'spl_ic_mou_7', 'spl_ic_mou_8', 'isd_ic_mou_6', 'isd_ic_mou_7', 'isd_ic_mou_8', 'ic_others_6', 'ic_others_7', 'ic_others_8'])
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  total_og_mou_6  total_og_mou_7  \
# 0    197.385   214.816   213.803            0.00            0.00
# 7   1069.180  1349.850  3171.480          487.53          609.24
# 8    378.721   492.223   137.362          508.36          431.66
# 21   514.453   597.753   637.760          860.34         1028.79
# 23    74.350   193.897   366.966          134.38          140.04
#
#     total_og_mou_8  total_ic_mou_6  total_ic_mou_7  total_ic_mou_8  \
# 0             0.00            0.00            0.00            5.44
# 7           350.16          626.46          558.04          428.74
# 8           171.56          103.86           28.49           16.54
# 21         1068.54          207.09          131.89          261.04
# 23          239.48          119.58          222.89          298.33
#
#     total_rech_num_6  ...  roam_any_8  local_any_6  local_any_7  local_any_8  \
# 0                  4  ...           0            0            0            1
# ...

# %%
prime1_class1 = prime1_class1.drop(columns=['max_rech_amt_6', 'max_rech_amt_7', 'max_rech_amt_8', 'max_rech_data_6', 'max_rech_data_7', 'max_rech_data_8'])
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  total_og_mou_6  total_og_mou_7  \
# 0    197.385   214.816   213.803            0.00            0.00
# 7   1069.180  1349.850  3171.480          487.53          609.24
# 8    378.721   492.223   137.362          508.36          431.66
# 21   514.453   597.753   637.760          860.34         1028.79
# 23    74.350   193.897   366.966          134.38          140.04
#
#     total_og_mou_8  total_ic_mou_6  total_ic_mou_7  total_ic_mou_8  \
# 0             0.00            0.00            0.00            5.44
# 7           350.16          626.46          558.04          428.74
# 8           171.56          103.86           28.49           16.54
# 21         1068.54          207.09          131.89          261.04
# 23          239.48          119.58          222.89          298.33
#
#     total_rech_num_6  ...  roam_any_8  local_any_6  local_any_7  local_any_8  \
# 0                  4  ...           0            0            0            1
# ...

# %%
## We have obtained classification for isd, local, standard, roaming 7 special data charges
## now we remove the total charges column
prime1_class1 = prime1_class1.drop(columns=['total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8', 'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8', 'total_data_rech_amt_6', 'total_data_rech_amt_7', 'total_data_rech_amt_8'])
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  total_og_mou_6  total_og_mou_7  \
# 0    197.385   214.816   213.803            0.00            0.00
# 7   1069.180  1349.850  3171.480          487.53          609.24
# 8    378.721   492.223   137.362          508.36          431.66
# 21   514.453   597.753   637.760          860.34         1028.79
# 23    74.350   193.897   366.966          134.38          140.04
#
#     total_og_mou_8  total_ic_mou_6  total_ic_mou_7  total_ic_mou_8  \
# 0             0.00            0.00            0.00            5.44
# 7           350.16          626.46          558.04          428.74
# 8           171.56          103.86           28.49           16.54
# 21         1068.54          207.09          131.89          261.04
# 23          239.48          119.58          222.89          298.33
#
#     total_rech_num_6  ...  roam_any_8  local_any_6  local_any_7  local_any_8  \
# 0                  4  ...           0            0            0            1
# ...

# %%
## Calculating 2G & 3G data used in MBs
prime1_class1['data_used_6'] = prime1_class1[['vol_2g_mb_6', 'vol_3g_mb_6', 'jun_vbc_3g']].sum(axis=1)
prime1_class1['data_used_7'] = prime1_class1[['vol_2g_mb_7', 'vol_3g_mb_7', 'jul_vbc_3g']].sum(axis=1)
prime1_class1['data_used_8'] = prime1_class1[['vol_2g_mb_8', 'vol_3g_mb_8', 'aug_vbc_3g']].sum(axis=1)
prime1_class1 = prime1_class1.drop(columns=['vol_2g_mb_6', 'vol_2g_mb_7', 'vol_2g_mb_8', 'vol_3g_mb_6', 'vol_3g_mb_7', 'vol_3g_mb_8', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g', 'sep_vbc_3g'])
prime1_class1 = prime1_class1.drop(columns=['total_rech_num_6', 'total_rech_num_7', 'total_rech_num_8', 'total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8'])
prime1_class1 = prime1_class1.drop(columns=['count_rech_2g_6', 'count_rech_2g_7', 'count_rech_2g_8', 'count_rech_3g_6', 'count_rech_3g_7', 'count_rech_3g_8'])
prime1_class1.head()
# Out:
#       arpu_6    arpu_7    arpu_8  total_og_mou_6  total_og_mou_7  \
# 0    197.385   214.816   213.803            0.00            0.00
# 7   1069.180  1349.850  3171.480          487.53          609.24
# 8    378.721   492.223   137.362          508.36          431.66
# 21   514.453   597.753   637.760          860.34         1028.79
# 23    74.350   193.897   366.966          134.38          140.04
#
#     total_og_mou_8  total_ic_mou_6  total_ic_mou_7  total_ic_mou_8  \
# 0             0.00            0.00            0.00            5.44
# 7           350.16          626.46          558.04          428.74
# 8           171.56          103.86           28.49           16.54
# 21         1068.54          207.09          131.89          261.04
# 23          239.48          119.58          222.89          298.33
#
#     last_day_rch_amt_6  ...  local_any_8  std_any_6  std_any_7  std_any_8  \
# 0                  252  ...            1          0          0          0
# ...

# %%
## Doing a Train Test Split for prime1_class1 & prime1_class2 into 70/30
X_train, X_test, y_train, y_test = train_test_split(prime1_class1, prime1_class2, train_size=0.7, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
logreg= LogisticRegression()

# %%
from sklearn.feature_selection import RFE

rfe = RFE(logreg, step=20)

rfe = rfe.fit(X_train, y_train)

# %%
col = X_train.columns[rfe.support_]

# %%
import statsmodels.api as sm

# %%
X_train_sm = sm.add_constant(X_train[col])
mainboard = sm.GLM(y_train,X_train_sm, family = sm.families.Binomial())
ATD = mainboard.fit()
ATD.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                  Churn   No. Observations:                21000
# Model:                            GLM   Df Residuals:                    20973
# Model Family:                Binomial   Df Model:                           26
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -3648.1
# Date:                Sun, 03 Mar 2024   Deviance:                       7296.2
# Time:                        20:35:02   Pearson chi2:                 3.73e+05
# No. Iterations:                     8   Pseudo R-squ. (CS):             0.2006
# Covariance Type:            nonrobust
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
##Checking VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['Features'] = X_train[col].columns
vif['VIF'] = [variance_inflation_factor(X_train[col].values, i) for i in range(X_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#               Features    VIF
# 17         local_any_7  44.71
# 16         local_any_6  39.69
# 18         local_any_8  29.67
# 20           std_any_7  12.89
# 19           std_any_6  12.43
# 21           std_any_8  11.63
# 22           spl_any_6   5.44
# 3       total_ic_mou_8   5.32
# 2       total_ic_mou_7   5.20
# 24           spl_any_8   5.11
# 23           spl_any_7   5.05
# 25         data_used_8   3.53
# 8            arpu_2g_8   3.40
# 0               arpu_6   3.33
# 12         sachet_2g_7   3.29
# 14                 aon   2.83
# 13         sachet_2g_8   2.57
# 7            arpu_2g_7   2.47
# 11         sachet_2g_6   2.43
# 1       total_og_mou_8   2.22
# 6            arpu_3g_6   2.13
# 4   last_day_rch_amt_6   1.83
# 10        monthly_2g_7   1.78
# 5   last_day_rch_amt_8   1.75
# 9         monthly_2g_6   1.71
# 15          roam_any_8   1.30

# %%
## Reshaping
y_train_pred = ATD.predict(X_train_sm).values.reshape(-1)

# %%
y_train_pred_final = pd.DataFrame({'Converted':y_train.values, 'Converted_prob':y_train_pred})
y_train_pred_final['Converted_prob'] = y_train_pred
y_train_pred_final['predicted'] = y_train_pred_final.Converted_prob.map(lambda x: 1 if x > 0.5 else 0)
y_train_pred_final.head()
# Out:
#    Converted  Converted_prob  predicted
# 0          1        0.598133          1
# 1          0        0.148086          0
# 2          0        0.008357          0
# 3          0        0.044076          0
# 4          0        0.008998          0

# %%
## VIF is very high for local_any_7, local_any_6, local_any_8, std_any_7, std_any_6, std_any_8

# %%
##Creating a confusion matrix for Test data
from sklearn.metrics import confusion_matrix
confusion = metrics.confusion_matrix(y_train_pred_final.Converted, y_train_pred_final.predicted )
print(confusion)
# Out:
# [[18906   354]
#  [  917   823]]

# %%
## Checking for cut-off value from  (0.1,0.2,0.3......1.0)
## Taking cut-off as 0.1
y_train_pred_final['final_predicted'] = y_train_pred_final.Converted_prob.map( lambda x: 1 if x > 0.1 else 0)
y_train_pred_final.head()
# Out:
#    Converted  Converted_prob  predicted  final_predicted
# 0          1        0.598133          1                1
# 1          0        0.148086          0                1
# 2          0        0.008357          0                0
# 3          0        0.044076          0                0
# 4          0        0.008998          0                0

# %%
con2 = metrics.confusion_matrix(y_train_pred_final.Converted, y_train_pred_final.final_predicted )
con2
# Out:
# array([[17220,  2040],
#        [  359,  1381]], dtype=int64)

# %%
TP = con2[1,1]
TN = con2[0,0]
FP = con2[0,1]
FN = con2[1,0]

# %%
## Sensitivity
TP/float(TP+FP)
# Out:
# 0.4036831335866706

# %%
##Specificity
TN / float(TN+FP)
# Out:
# 0.8940809968847352

# %%
##Precision
TP / float(TP+FN)
# Out:
# 0.7936781609195402

# %%
###Hence we have created a logistic Regression model that has the below values
# Sensitivity = ~40%
# Specificity = ~89%
# Precision = ~ 79%
